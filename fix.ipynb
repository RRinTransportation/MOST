# %%
import pandas as pd

# %%
data = pd.read_csv('data/dashboard.csv')

# %%
# replace lda_topic "traffic behaviour" with "travel behaviour"
data['lda_topic'] = data['lda_topic'].replace('Traffic behaviour', 'Travel behaviour')

# %%
data['lda_topic'].value_counts()
data.to_csv('data/dashboard.csv', index=False)
